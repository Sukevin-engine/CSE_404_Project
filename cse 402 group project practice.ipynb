# %%
#!pip install tensorflow

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as image

# %%
attempt1=image.imread("Achaemenid architecture/000000.jpg")
attempt1.shape
# Out:
# (442, 1000, 3)

# %%
attempt2=image.imread("Achaemenid architecture/000002.jpg")
attempt2.shape
# Out:
# (650, 1000, 3)

# %%
plt.imshow(attempt1)

# %%
attempt3=image.imread("Achaemenid architecture/000448.jpg")
attempt3.shape
# Out:
# (523, 1000, 3)

# %%
plt.imshow(attempt3)

# %%
test1=np.array(attempt3)
test1.resize((442,1000,3))
plt.imshow(test1)

# %%
plt.imshow(attempt2)

# %%
test2=np.array(attempt2)
test2.resize(442,1000,3)
plt.imshow(test2)

# %%
test2.resize(650,1000,3)
plt.imshow(test2)
